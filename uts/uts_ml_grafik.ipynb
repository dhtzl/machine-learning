# %%
import pandas as pd
import matplotlib.pyplot as plt

p = ['kopiko', 'torabika', 'beng beng', 'choki-choki', 'teh pucuk', 'energen']
b = [52,39,78,13,78,29]

pb = {'names':p, 'stok':b}

data = pd.DataFrame(data=pb, columns=['names','stok'])
print(data)

data.plot(x='names', y='stok', marker='o',)
# Out:
#          names  stok
# 0       kopiko    52
# 1     torabika    39
# 2    beng beng    78
# 3  choki-choki    13
# 4    teh pucuk    78
# 5      energen    29
# <AxesSubplot: xlabel='names'>
