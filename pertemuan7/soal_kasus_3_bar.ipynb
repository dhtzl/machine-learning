# %%
import pandas as pd
import matplotlib.pyplot as plt

p = ['gelas', 'piring', 'mangkok']
b = [100, 200, 300]

pb = {'product':p, 'barang':b}

data = pd.DataFrame(data=pb, columns=['product','barang'])
print(data)

data.plot(x='product', y='barang')
# Out:
#    product  barang
# 0    gelas     100
# 1   piring     200
# 2  mangkok     300
# <AxesSubplot: xlabel='product'>
